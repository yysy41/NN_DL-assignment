# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( 
                in_channels=1,  
                out_channels=32,
                kernel_size=7,
                stride=1,
                padding=3,  # padding=3保证输出与输入大小相同
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( 
             nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=5,
                stride=1,
                padding=2,  # padding=2保证输出与输入大小相同
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)  # 最大池化，窗口大小 = 2x2，步幅 = 2
         

        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view( x.size(0), -1 )  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# D:\py3.11\Lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\19914\AppData\Local\Temp\ipykernel_24556\1784665630.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# D:\py3.11\Lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\19914\AppData\Local\Temp\ipykernel_24556\1784665630.py:74: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.154 ==========
# ========== 40 ===== ===== test accuracy is  0.328 ==========
# ========== 60 ===== ===== test accuracy is  0.43 ==========
# ========== 80 ===== ===== test accuracy is  0.56 ==========
# ========== 100 ===== ===== test accuracy is  0.602 ==========
# ========== 120 ===== ===== test accuracy is  0.664 ==========
# ========== 140 ===== ===== test accuracy is  0.706 ==========
# ========== 160 ===== ===== test accuracy is  0.72 ==========
# ========== 180 ===== ===== test accuracy is  0.74 ==========
# ========== 200 ===== ===== test accuracy is  0.754 ==========
# ========== 220 ===== ===== test accuracy is  0.794 ==========
# ========== 240 ===== ===== test accuracy is  0.79 ==========
# ========== 260 ===== ===== test accuracy is  0.846 ==========
# ========== 280 ===== ===== test accuracy is  0.812 ==========
# ========== 300 ===== ===== test accuracy is  0.854 ==========
# ========== 320 ===== ===== test accuracy is  0.862 ==========
# ========== 340 ===== ===== test accuracy is  0.874 ==========
# ========== 360 ===== ===== test accuracy is  0.874 ==========
# ========== 380 ===== ===== test accuracy is  0.886 ==========
# ========== 400 ===== ===== test accuracy is  0.88 ==========
# ========== 420 ===== ===== test accuracy is  0.882 ==========
# ========== 440 ===== ===== test accuracy is  0.908 ==========
# ========== 460 ===== ===== test accuracy is  0.892 ==========
# ========== 480 ===== ===== test accuracy is  0.892 ==========
# ========== 500 ===== ===== test accuracy is  0.902 ==========
# ========== 520 ===== ===== test accuracy is  0.906 ==========
# ========== 540 ===== ===== test accuracy is  0.916 ==========
# ========== 560 ===== ===== test accuracy is  0.906 ==========
# ========== 580 ===== ===== test accuracy is  0.922 ==========
# ========== 600 ===== ===== test accuracy is  0.906 ==========
# ========== 620 ===== ===== test accuracy is  0.922 ==========
# ========== 640 ===== ===== test accuracy is  0.924 ==========
# ========== 660 ===== ===== test accuracy is  0.92 ==========
# ========== 680 ===== ===== test accuracy is  0.932 ==========
# ========== 700 ===== ===== test accuracy is  0.92 ==========
# ========== 720 ===== ===== test accuracy is  0.93 ==========
# ========== 740 ===== ===== test accuracy is  0.928 ==========
# ========== 760 ===== ===== test accuracy is  0.934 ==========
# ========== 780 ===== ===== test accuracy is  0.944 ==========
# ========== 800 ===== ===== test accuracy is  0.932 ==========
# ========== 820 ===== ===== test accuracy is  0.93 ==========
# ========== 840 ===== ===== test accuracy is  0.944 ==========
# ========== 860 ===== ===== test accuracy is  0.928 ==========
# ========== 880 ===== ===== test accuracy is  0.938 ==========
# ========== 900 ===== ===== test accuracy is  0.93 ==========
# ========== 920 ===== ===== test accuracy is  0.944 ==========
# ========== 940 ===== ===== test accuracy is  0.95 ==========
# ========== 960 ===== ===== test accuracy is  0.936 ==========
# ========== 980 ===== ===== test accuracy is  0.928 ==========
# ========== 1000 ===== ===== test accuracy is  0.95 ==========
# ========== 1020 ===== ===== test accuracy is  0.946 ==========
# ========== 1040 ===== ===== test accuracy is  0.93 ==========
# ========== 1060 ===== ===== test accuracy is  0.942 ==========
# ========== 1080 ===== ===== test accuracy is  0.948 ==========
# ========== 1100 ===== ===== test accuracy is  0.948 ==========
# ========== 1120 ===== ===== test accuracy is  0.948 ==========
# ========== 1140 ===== ===== test accuracy is  0.94 ==========
# ========== 1160 ===== ===== test accuracy is  0.942 ==========
# ========== 1180 ===== ===== test accuracy is  0.948 ==========
# ========== 20 ===== ===== test accuracy is  0.94 ==========
# ========== 40 ===== ===== test accuracy is  0.95 ==========
# ========== 60 ===== ===== test accuracy is  0.946 ==========
# ========== 80 ===== ===== test accuracy is  0.948 ==========
# ========== 100 ===== ===== test accuracy is  0.954 ==========
# ========== 120 ===== ===== test accuracy is  0.948 ==========
# ========== 140 ===== ===== test accuracy is  0.954 ==========
# ========== 160 ===== ===== test accuracy is  0.958 ==========
# ========== 180 ===== ===== test accuracy is  0.956 ==========
# ========== 200 ===== ===== test accuracy is  0.954 ==========
# ========== 220 ===== ===== test accuracy is  0.962 ==========
# ========== 240 ===== ===== test accuracy is  0.958 ==========
# ========== 260 ===== ===== test accuracy is  0.954 ==========
# ========== 280 ===== ===== test accuracy is  0.946 ==========
# ========== 300 ===== ===== test accuracy is  0.956 ==========
# ========== 320 ===== ===== test accuracy is  0.954 ==========
# ========== 340 ===== ===== test accuracy is  0.944 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.948 ==========
# ========== 400 ===== ===== test accuracy is  0.954 ==========
# ========== 420 ===== ===== test accuracy is  0.952 ==========
# ========== 440 ===== ===== test accuracy is  0.95 ==========
# ========== 460 ===== ===== test accuracy is  0.954 ==========
# ========== 480 ===== ===== test accuracy is  0.956 ==========
# ========== 500 ===== ===== test accuracy is  0.956 ==========
# ========== 520 ===== ===== test accuracy is  0.964 ==========
# ========== 540 ===== ===== test accuracy is  0.958 ==========
# ========== 560 ===== ===== test accuracy is  0.96 ==========
# ========== 580 ===== ===== test accuracy is  0.962 ==========
# ========== 600 ===== ===== test accuracy is  0.964 ==========
# ========== 620 ===== ===== test accuracy is  0.958 ==========
# ========== 640 ===== ===== test accuracy is  0.958 ==========
# ========== 660 ===== ===== test accuracy is  0.97 ==========
# ========== 680 ===== ===== test accuracy is  0.954 ==========
# ========== 700 ===== ===== test accuracy is  0.966 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.96 ==========
# ========== 760 ===== ===== test accuracy is  0.96 ==========
# ========== 780 ===== ===== test accuracy is  0.958 ==========
# ========== 800 ===== ===== test accuracy is  0.964 ==========
# ========== 820 ===== ===== test accuracy is  0.968 ==========
# ========== 840 ===== ===== test accuracy is  0.954 ==========
# ========== 860 ===== ===== test accuracy is  0.968 ==========
# ========== 880 ===== ===== test accuracy is  0.958 ==========
# ========== 900 ===== ===== test accuracy is  0.958 ==========
# ========== 920 ===== ===== test accuracy is  0.952 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.974 ==========
# ========== 980 ===== ===== test accuracy is  0.962 ==========
# ========== 1000 ===== ===== test accuracy is  0.968 ==========
# ========== 1020 ===== ===== test accuracy is  0.968 ==========
# ========== 1040 ===== ===== test accuracy is  0.972 ==========
# ========== 1060 ===== ===== test accuracy is  0.97 ==========
# ========== 1080 ===== ===== test accuracy is  0.972 ==========
# ========== 1100 ===== ===== test accuracy is  0.972 ==========
# ========== 1120 ===== ===== test accuracy is  0.97 ==========
# ========== 1140 ===== ===== test accuracy is  0.964 ==========
# ========== 1160 ===== ===== test accuracy is  0.968 ==========
# ========== 1180 ===== ===== test accuracy is  0.966 ==========
# ========== 20 ===== ===== test accuracy is  0.966 ==========
# ========== 40 ===== ===== test accuracy is  0.962 ==========
# ========== 60 ===== ===== test accuracy is  0.974 ==========
# ========== 80 ===== ===== test accuracy is  0.972 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.962 ==========
# ========== 140 ===== ===== test accuracy is  0.966 ==========
# ========== 160 ===== ===== test accuracy is  0.962 ==========
# ========== 180 ===== ===== test accuracy is  0.97 ==========
# ========== 200 ===== ===== test accuracy is  0.964 ==========
# ========== 220 ===== ===== test accuracy is  0.966 ==========
# ========== 240 ===== ===== test accuracy is  0.96 ==========
# ========== 260 ===== ===== test accuracy is  0.976 ==========
# ========== 280 ===== ===== test accuracy is  0.964 ==========
# ========== 300 ===== ===== test accuracy is  0.974 ==========
# ========== 320 ===== ===== test accuracy is  0.966 ==========
# ========== 340 ===== ===== test accuracy is  0.968 ==========
# ========== 360 ===== ===== test accuracy is  0.968 ==========
# ========== 380 ===== ===== test accuracy is  0.972 ==========
# ========== 400 ===== ===== test accuracy is  0.974 ==========
# ========== 420 ===== ===== test accuracy is  0.974 ==========
# ========== 440 ===== ===== test accuracy is  0.97 ==========
# ========== 460 ===== ===== test accuracy is  0.968 ==========
# ========== 480 ===== ===== test accuracy is  0.966 ==========
# ========== 500 ===== ===== test accuracy is  0.972 ==========
# ========== 520 ===== ===== test accuracy is  0.978 ==========
# ========== 540 ===== ===== test accuracy is  0.97 ==========
# ========== 560 ===== ===== test accuracy is  0.966 ==========
# ========== 580 ===== ===== test accuracy is  0.966 ==========
# ========== 600 ===== ===== test accuracy is  0.962 ==========
# ========== 620 ===== ===== test accuracy is  0.976 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.972 ==========
# ========== 680 ===== ===== test accuracy is  0.97 ==========
# ========== 700 ===== ===== test accuracy is  0.978 ==========
# ========== 720 ===== ===== test accuracy is  0.974 ==========
# ========== 740 ===== ===== test accuracy is  0.972 ==========
# ========== 760 ===== ===== test accuracy is  0.972 ==========
# ========== 780 ===== ===== test accuracy is  0.976 ==========
# ========== 800 ===== ===== test accuracy is  0.972 ==========
# ========== 820 ===== ===== test accuracy is  0.976 ==========
# ========== 840 ===== ===== test accuracy is  0.978 ==========
# ========== 860 ===== ===== test accuracy is  0.976 ==========
# ========== 880 ===== ===== test accuracy is  0.972 ==========
# ========== 900 ===== ===== test accuracy is  0.978 ==========
# ========== 920 ===== ===== test accuracy is  0.982 ==========
# ========== 940 ===== ===== test accuracy is  0.986 ==========
# ========== 960 ===== ===== test accuracy is  0.98 ==========
# ========== 980 ===== ===== test accuracy is  0.974 ==========
# ========== 1000 ===== ===== test accuracy is  0.974 ==========
# ========== 1020 ===== ===== test accuracy is  0.964 ==========
# ========== 1040 ===== ===== test accuracy is  0.976 ==========
# ========== 1060 ===== ===== test accuracy is  0.97 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.984 ==========
# ========== 1120 ===== ===== test accuracy is  0.976 ==========
# ========== 1140 ===== ===== test accuracy is  0.972 ==========
# ========== 1160 ===== ===== test accuracy is  0.966 ==========
# ========== 1180 ===== ===== test accuracy is  0.97 ==========
